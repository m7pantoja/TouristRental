# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/clean_seville_2022.csv')
df_non_shared = df[df['Tipo_Inmueble'] != 'Habitacion_Compartida']
df.head()
# Out:
#       Key  Host_Key       Distrito       Barrio      Tipo_Inmueble  Precio  \
# 0  108236    560040  Casco_Antiguo  San Lorenzo  Inmueble_Completo      89
# 1  898157   4790497  Casco_Antiguo      Alfalfa  Inmueble_Completo      94
# 2  661655   3340359  Casco_Antiguo        Feria  Inmueble_Completo     151
# 3  108568    589600  Casco_Antiguo  San Lorenzo  Inmueble_Completo     111
# 4  899093   4790497  Casco_Antiguo  San Lorenzo  Inmueble_Completo     122
#
#    Min_Nights  Anuncios_Totales_del_Host  Capacidad  Dormitorios  Camas  \
# 0           2                          2        6.0          2.0    3.0
# 1           3                         33        3.0          1.0    3.0
# 2           2                          7        6.0          2.0    4.0
# 3           3                         10        6.0          2.0    4.0
# 4           3                         33        4.0          2.0    3.0
#
#    Baños  Precio/Capacidad
# 0    1.0         14.833333
# 1    1.0         31.333333
# 2    2.0         25.166667
# 3    1.0         18.500000
# 4    2.0         30.500000

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10,10)
ax.set_axisbelow(True)
ax.xaxis.grid(color='gray', linestyle='dashed')

ax
sns.boxplot(data = df_non_shared, 
            x = 'Precio', 
            y = 'Distrito',
            palette = 'muted',
            showfliers = False)

ax.set_yticklabels(['Casco Antiguo','Macarena','Nervión','Cerro - Amate','Triana','Sur','La Palmera - Bellavista', 'Este - Alcosa - Torreblanca',
                    'Santa Justa - San Pablo', 'Norte', 'Los Remedios'],
                    fontdict = {'fontsize' : 13})
plt.xticks(fontsize = 12)
ax.set_ylabel('Distrito', fontdict={'fontsize': 15})
ax.set_xlabel('\n Precio (€)',fontdict={'fontsize':15})
# Out:
# Text(0.5, 0, '\n Precio (€)')

# %%
density_data = df['Distrito'].value_counts()

plt.style.use('seaborn-v0_8')

plt.figure(figsize = (8,8))
plt.pie(x = density_data.values, labels = density_data.keys(), autopct='%1.2f%%',
        textprops= {'fontsize': 12})
# Out:
# ([<matplotlib.patches.Wedge at 0x21850e1a710>,
#   <matplotlib.patches.Wedge at 0x21850e9cdd0>,
#   <matplotlib.patches.Wedge at 0x21850e9ea10>,
#   <matplotlib.patches.Wedge at 0x21850e9e050>,
#   <matplotlib.patches.Wedge at 0x21850eb2990>,
#   <matplotlib.patches.Wedge at 0x21850ebc7d0>,
#   <matplotlib.patches.Wedge at 0x21850e9e550>,
#   <matplotlib.patches.Wedge at 0x21850ebf4d0>,
#   <matplotlib.patches.Wedge at 0x21850ec9290>,
#   <matplotlib.patches.Wedge at 0x21850eb3990>,
#   <matplotlib.patches.Wedge at 0x21850eb1a90>],
#  [Text(-0.7054766186713334, 0.8439802962795175, 'Casco_Antiguo'),
#   Text(0.2047910501568583, -1.0807685347823794, 'Triana'),
#   Text(0.7226181802903858, -0.8293509302543838, 'Nervion'),
#   Text(0.9103147566945092, -0.6175168368103144, 'Macarena'),
#   Text(0.9950036772829792, -0.4690071238194031, 'San_Pablo_Santa_Justa'),
#   Text(1.0398319936280993, -0.3588167011545205, 'Sur'),
#   Text(1.0686167677445133, -0.260879672828814, 'Los_Remedios'),
#   Text(1.084795429723495, -0.1822604610194381, 'Bellavista_La_Palmera'),
#   Text(1.0927038307097605, -0.12648453799660686, 'Este_Alcosa_Torreblanca'),
#   Text(1.097467929388326, -0.0745931897970601, 'Norte'),
#   Text(1.0997238471103716, -0.02464670559656823, 'Cerro_Amate')],
#  [Text(-0.3848054283661818, 0.4603528888797368, '72.16%'),
#   Text(0.11170420917646816, -0.5895101098812978, '11.64%'),
#   Text(0.3941553710674831, -0.45237323468420926, '5.22%'),
#   Text(0.4965353218333686, -0.3368273655328987, '3.00%'),
#   Text(0.5427292785179886, -0.2558220675378562, '1.96%'),
#   Text(0.5671810874335087, -0.19571820062973844, '1.49%'),
#   Text(0.582881873315189, -0.14229800336117127, '1.47%'),
#   Text(0.5917065980309972, -0.0994147969196935, '0.86%'),
#   Text(0.5960202712962329, -0.06899156617996736, '0.77%'),
#   Text(0.5986188705754505, -0.04068719443476005, '0.73%'),
#   Text(0.5998493711511118, -0.013443657598128125, '0.71%')])
